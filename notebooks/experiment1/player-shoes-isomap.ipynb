# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import networkx as nx
import sklearn

# %%
pos_score_dict = {
    'Guard': 1,
    'Forward': 2,
    'Center': 3
}

player_df = pd.read_csv('./player-shoes-data.csv')
player_df['pos_score'] = player_df['Position'].apply(lambda x: pos_score_dict[x])
player_df
# Out:
#                        Player  \
# 0            Precious Achiuwa
# 1                Steven Adams
# 2                 Bam Adebayo
# 3                Santi Aldama
# 4    Nickeil Alexander-Walker
# ..                        ...
# 441            Thaddeus Young
# 442                Trae Young
# 443            Omer Yurtseven
# 444               Cody Zeller
# 445               Ivica Zubac
#
#                                       Player Page Link  \
# 0    https://ballershoesdb.com/players/precious-ach...
# 1      https://ballershoesdb.com/players/steven-adams/
# 2       https://ballershoesdb.com/players/bam-adebayo/
# 3      https://ballershoesdb.com/players/santi-aldama/
# 4    https://ballershoesdb.com/players/nickeil-alex...
# ..                                                 ...
# 441  https://ballershoesdb.com/players/thaddeus-young/
# 442      https://ballershoesdb.com/players/trae-young/
# 443  https://ballershoesdb.com/players/omer-yurtseven/
# 444     https://ballershoesdb.com/players/cody-zeller/
# 445     https://ballershoesdb.com/players/ivica-zubac/
#
#               Current Kicks Position  pos_score
# 0         Anta Daringly 3.0  Forward          2
# 1    New Balance Two Wxy V3   Center          3
# 2             Air Jordan 37  Forward          2
# 3          Nike Kyrie Low 5  Forward          2
# 4        Nike Kobe 5 Protro    Guard          1
# ..                      ...      ...        ...
# 441      Nike Kobe 6 Protro  Forward          2
# 442     Adidas Trae Young 2    Guard          1
# 443      Nike Kobe 5 Protro   Center          3
# 444           Air Jordan 37   Center          3
# 445  Adidas D.O.N. Issue #4   Center          3
#
# [446 rows x 5 columns]

# %%
import re
shoes_df = pd.read_csv('shoe-dataset.csv')
shoes_df['Number'] = shoes_df['Shoe Tag'].apply(lambda x: re.search(r'shoe_(\d+)\.jpg', x).group(1))
merged_df = shoes_df.merge(player_df, how='left', left_on='Shoe Name', right_on='Current Kicks')
merged_df = merged_df.dropna(subset=['Player'])
grouped_df = merged_df.groupby(['Number', 'Shoe Tag', 'Shoe Name', 'Style']).agg({'Player': 'count', 'pos_score': 'mean'}).reset_index()
# filtered_df = grouped_df[grouped_df['Player'] > 1]
sorted_df = grouped_df.copy()
sorted_df['Number'] = sorted_df['Number'].astype(int)
sorted_df = sorted_df.sort_values(by='Number')
shoe_files = list(sorted_df['Shoe Tag'].unique())
shoe_names = [x.replace('.jpg', '') for x in shoe_files]
shoe_pos_dict = sorted_df[['Shoe Tag', 'pos_score', 'Style']].set_index('Shoe Tag').to_dict(orient='index')
print(len(shoe_files), shoe_names[:5])
# Out:
# 58 ['shoe_12', 'shoe_50', 'shoe_52', 'shoe_54', 'shoe_63']

# %%
sorted_df.sort_values(by='pos_score')
# Out:
#     Number      Shoe Tag                   Shoe Name     Style  Player  \
# 0       12   shoe_12.jpg           Adidas BYW Select   Low Top       1
# 14     332  shoe_332.jpg  Nike Giannis Immortality 2   Low Top       2
# 16     348  shoe_348.jpg                   Nike Ja 1   Low Top       1
# 52     561  shoe_561.jpg        Under Armour Curry 7   Low Top       1
# 25     381  shoe_381.jpg                Nike Kyrie 3   Mid Top       2
# 35     419  shoe_419.jpg                   Nike PG 3   Low Top       1
# 9      275  shoe_275.jpg      Li-Ning Way of Wade 10   Low Top       2
# 1      120  shoe_120.jpg               Air Jordan 35  High Top       1
# 40     439  shoe_439.jpg           Nike Zoom Freak 1   Low Top       1
# 55      67   shoe_67.jpg        Adidas Harden Vol. 4   Low Top       1
# 54      63   shoe_63.jpg    Adidas Harden Stepback 3   Low Top       1
# 47     502  shoe_502.jpg                  Puma MB.02   Mid Top       1
# 57      85   shoe_85.jpg  Adidas Pro Bounce 2019 Low   Low Top       1
# 10     281  shoe_281.jpg       Li-Ning Way of Wade 7   Low Top       1
# 51      54   shoe_54.jpg            Adidas Exhibit A   Low Top       7
# 49     506  shoe_506.jpg        Puma TRC Blaze Court   Low Top       3
# 22     372  shoe_372.jpg         Nike Kobe AD Exodus   Low Top       5
# 28     385  shoe_385.jpg                Nike Kyrie 7   Mid Top      16
# 21     370  shoe_370.jpg          Nike Kobe 6 Protro   Low Top      30
# 29     393  shoe_393.jpg            Nike Kyrie Low 4   Low Top       4
# 4      222  shoe_222.jpg               Jordan Luka 1   Low Top       2
# 48     503  shoe_503.jpg             Puma Rise Nitro   Mid Top       5
# 43     442  shoe_442.jpg           Nike Zoom Freak 4   Low Top      17
# 20     369  shoe_369.jpg          Nike Kobe 5 Protro   Low Top      29
# 50      52   shoe_52.jpg               Adidas Dame 8   Low Top      12
# 30     394  shoe_394.jpg            Nike Kyrie Low 5   Low Top      10
# 38     422  shoe_422.jpg                   Nike PG 6   Low Top      25
# 3      122  shoe_122.jpg               Air Jordan 37  High Top      11
# 27     384  shoe_384.jpg                Nike Kyrie 6  High Top       5
# 2      121  shoe_121.jpg               Air Jordan 36  High Top       6
# 37     421  shoe_421.jpg                   Nike PG 5   Low Top       7
# 18     353  shoe_353.jpg                  Nike KD 14   Mid Top       8
# 11     300  shoe_300.jpg      New Balance Two Wxy V3   Low Top       9
# 32     402  shoe_402.jpg              Nike LeBron 18  High Top       1
# 36     420  shoe_420.jpg                   Nike PG 4   Low Top       1
# 46     501  shoe_501.jpg                  Puma MB.01   Mid Top       1
# 45      50   shoe_50.jpg               Adidas Dame 6   Low Top       1
# 33     404  shoe_404.jpg              Nike LeBron 20   Low Top      15
# 12     304  shoe_304.jpg             Nike Air Deldon  High Top       1
# 31     401  shoe_401.jpg              Nike LeBron 17  High Top       1
# 53     570  shoe_570.jpg    Under Armour Flow FUTR X   Low Top       1
# 23     373  shoe_373.jpg            Nike Kobe AD Mid   Mid Top       1
# 5      237  shoe_237.jpg      Jordan React Elevation  High Top       1
# 6      242  shoe_242.jpg      Jordan Super.Fly MVP L  High Top       1
# 8      256  shoe_256.jpg               Jordan Zion 2   Mid Top       3
# 7      244  shoe_244.jpg              Jordan Tatum 1   Low Top       1
# 19     354  shoe_354.jpg                  Nike KD 15   Low Top      16
# 13     330  shoe_330.jpg         Nike Cosmic Unity 2   Low Top       3
# 42     441  shoe_441.jpg           Nike Zoom Freak 3   Low Top       3
# 26     383  shoe_383.jpg                Nike Kyrie 5  High Top       2
# 15     341  shoe_341.jpg            Nike Hyperdunk X  High Top       3
# 17     352  shoe_352.jpg                  Nike KD 13   Mid Top       3
# 24     378  shoe_378.jpg              Nike Kybrid S2   Mid Top       1
# 56      69   shoe_69.jpg        Adidas Harden Vol. 6   Low Top       1
# 39     426  shoe_426.jpg        Nike Renew Elevate 3   Low Top       1
# 34     410  shoe_410.jpg      Nike LeBron Soldier 14  High Top       1
# 44     475  shoe_475.jpg            Nike Zoom Rize 2   Mid Top       2
# 41     440  shoe_440.jpg           Nike Zoom Freak 2   Low Top       1
#
#     pos_score
# 0    1.000000
# 14   1.000000
# 16   1.000000
# 52   1.000000
# 25   1.000000
# 35   1.000000
# 9    1.000000
# 1    1.000000
# 40   1.000000
# 55   1.000000
# 54   1.000000
# 47   1.000000
# 57   1.000000
# 10   1.000000
# 51   1.142857
# 49   1.333333
# 22   1.400000
# 28   1.437500
# 21   1.466667
# 29   1.500000
# 4    1.500000
# 48   1.600000
# 43   1.647059
# 20   1.655172
# 50   1.666667
# 30   1.700000
# 38   1.720000
# 3    1.727273
# 27   1.800000
# 2    1.833333
# 37   1.857143
# 18   1.875000
# 11   1.888889
# 32   2.000000
# 36   2.000000
# 46   2.000000
# 45   2.000000
# 33   2.000000
# 12   2.000000
# 31   2.000000
# 53   2.000000
# 23   2.000000
# 5    2.000000
# 6    2.000000
# 8    2.000000
# 7    2.000000
# 19   2.062500
# 13   2.333333
# 42   2.333333
# 26   2.500000
# 15   2.666667
# 17   2.666667
# 24   3.000000
# 56   3.000000
# 39   3.000000
# 34   3.000000
# 44   3.000000
# 41   3.000000

# %%
shoe_pos_dict
# Out:
# {'shoe_12.jpg': {'pos_score': 1.0, 'Style': 'Low Top'},
#  'shoe_50.jpg': {'pos_score': 2.0, 'Style': 'Low Top'},
#  'shoe_52.jpg': {'pos_score': 1.6666666666666667, 'Style': 'Low Top'},
#  'shoe_54.jpg': {'pos_score': 1.1428571428571428, 'Style': 'Low Top'},
#  'shoe_63.jpg': {'pos_score': 1.0, 'Style': 'Low Top'},
#  'shoe_67.jpg': {'pos_score': 1.0, 'Style': 'Low Top'},
#  'shoe_69.jpg': {'pos_score': 3.0, 'Style': 'Low Top'},
#  'shoe_85.jpg': {'pos_score': 1.0, 'Style': 'Low Top'},
#  'shoe_120.jpg': {'pos_score': 1.0, 'Style': 'High Top'},
#  'shoe_121.jpg': {'pos_score': 1.8333333333333333, 'Style': 'High Top'},
#  'shoe_122.jpg': {'pos_score': 1.7272727272727273, 'Style': 'High Top'},
#  'shoe_222.jpg': {'pos_score': 1.5, 'Style': 'Low Top'},
#  'shoe_237.jpg': {'pos_score': 2.0, 'Style': 'High Top'},
#  'shoe_242.jpg': {'pos_score': 2.0, 'Style': 'High Top'},
#  'shoe_244.jpg': {'pos_score': 2.0, 'Style': 'Low Top'},
#  'shoe_256.jpg': {'pos_score': 2.0, 'Style': 'Mid Top'},
#  'shoe_275.jpg': {'pos_score': 1.0, 'Style': 'Low Top'},
#  'shoe_281.jpg': {'pos_score': 1.0, 'Style': 'Low Top'},
#  'shoe_300.jpg': {'pos_score': 1.8888888888888888, 'Style': 'Low Top'},
#  'shoe_304.jpg': {'pos_score': 2.0, 'Style': 'High Top'},
#  'shoe_330.jpg': {'pos_score': 2.3333333333333335, 'Style': 'Low Top'},
#  'shoe_332.jpg': {'pos_score': 1.0, 'Style': 'Low Top'},
#  'shoe_341.jpg': {'pos_score': 2.6666666666666665, 'Style': 'High Top'},
#  'shoe_348.jpg': {'pos_score': 1.0, 'Style': 'Low Top'},
#  'shoe_352.jpg': {'pos_score': 2.6666666666666665, 'Style': 'Mid Top'},
#  'shoe_353.jpg': {'pos_score': 1.875, 'Style': 'Mid Top'},
#  'shoe_354.jpg': {'pos_score': 2.0625, 'Style': 'Low Top'},
#  'shoe_369.jpg': {'pos_score': 1.6551724137931034, 'Style': 'Low Top'},
#  'shoe_370.jpg': {'pos_score': 1.4666666666666666, 'Style': 'Low Top'},
#  'shoe_372.jpg': {'pos_score': 1.4, 'Style': 'Low Top'},
#  'shoe_373.jpg': {'pos_score': 2.0, 'Style': 'Mid Top'},
#  'shoe_378.jpg': {'pos_score': 3.0, 'Style': 'Mid Top'},
#  'shoe_381.jpg': {'pos_score': 1.0, 'Style': 'Mid Top'},
#  'shoe_383.jpg': {'pos_score': 2.5, 'Style': 'High Top'},
#  'shoe_384.jpg': {'pos_score': 1.8, 'Style': 'High Top'},
#  'shoe_385.jpg': {'pos_score': 1.4375, 'Style': 'Mid Top'},
#  'shoe_393.jpg': {'pos_score': 1.5, 'Style': 'Low Top'},
#  'shoe_394.jpg': {'pos_score': 1.7, 'Style': 'Low Top'},
#  'shoe_401.jpg': {'pos_score': 2.0, 'Style': 'High Top'},
#  'shoe_402.jpg': {'pos_score': 2.0, 'Style': 'High Top'},
#  'shoe_404.jpg': {'pos_score': 2.0, 'Style': 'Low Top'},
#  'shoe_410.jpg': {'pos_score': 3.0, 'Style': 'High Top'},
#  'shoe_419.jpg': {'pos_score': 1.0, 'Style': 'Low Top'},
#  'shoe_420.jpg': {'pos_score': 2.0, 'Style': 'Low Top'},
#  'shoe_421.jpg': {'pos_score': 1.8571428571428572, 'Style': 'Low Top'},
#  'shoe_422.jpg': {'pos_score': 1.72, 'Style': 'Low Top'},
#  'shoe_426.jpg': {'pos_score': 3.0, 'Style': 'Low Top'},
#  'shoe_439.jpg': {'pos_score': 1.0, 'Style': 'Low Top'},
#  'shoe_440.jpg': {'pos_score': 3.0, 'Style': 'Low Top'},
#  'shoe_441.jpg': {'pos_score': 2.3333333333333335, 'Style': 'Low Top'},
#  'shoe_442.jpg': {'pos_score': 1.6470588235294117, 'Style': 'Low Top'},
#  'shoe_475.jpg': {'pos_score': 3.0, 'Style': 'Mid Top'},
#  'shoe_501.jpg': {'pos_score': 2.0, 'Style': 'Mid Top'},
#  'shoe_502.jpg': {'pos_score': 1.0, 'Style': 'Mid Top'},
#  'shoe_503.jpg': {'pos_score': 1.6, 'Style': 'Mid Top'},
#  'shoe_506.jpg': {'pos_score': 1.3333333333333333, 'Style': 'Low Top'},
#  'shoe_561.jpg': {'pos_score': 1.0, 'Style': 'Low Top'},
#  'shoe_570.jpg': {'pos_score': 2.0, 'Style': 'Low Top'}}

# %%
import cv2
import numpy as np

def parse_png_directory(directory):
  """Parses a PNG directory and converts PNG files into NumPy arrays.

  Args:
    directory: The path to the PNG directory.

  Returns:
    A list of NumPy arrays, where each array represents one PNG file.
  """

  png_files = []
  for file in os.listdir(directory):
    if file.endswith(".png") and (file.replace('.png', '') in shoe_names or file.replace('_flipped.png', '') in shoe_names):
      png_files.append(file)

  numpy_arrays = []
  for png_file in png_files:
    numpy_array = cv2.imread(os.path.join(directory, png_file))
    grayscale_image = cv2.cvtColor(numpy_array, cv2.COLOR_RGB2GRAY)
    image_vec = np.reshape(grayscale_image, (-1,))
    numpy_arrays.append(image_vec)

  return np.vstack(numpy_arrays), np.array(png_files)

# %%
directory = "./cleaned_images"
images, png_files = parse_png_directory(directory)
print(images.shape)
print(png_files[:10])
# Out:
# (116, 100000)
# ['shoe_354_flipped.png' 'shoe_410.png' 'shoe_404.png'
#  'shoe_501_flipped.png' 'shoe_570.png' 'shoe_421_flipped.png'
#  'shoe_439.png' 'shoe_348_flipped.png' 'shoe_67_flipped.png'
#  'shoe_373_flipped.png']

# %%
fig, axs = plt.subplots(1, 3, figsize=(15,5))
random_nums = []
for i, ax in enumerate(axs.flatten()):
    random_num = np.random.choice(range(images.shape[0]))
    random_nums.append(random_num)
    ax.imshow(np.reshape(images[random_num], (250,400)), cmap="gray")
    ax.set_title(f"Image {random_num}")

# %%
def get_distance_matrix(W):
    # Assemble weighted edges matrix
    n = np.shape(W)[0]
    G = nx.DiGraph()
    for i in range(n):
        for j in range(n):
            G.add_weighted_edges_from([(i, j, min(W[i,j], W[j,i]))])
    
    # Implement dijkstra's algorithm to get distance matrix
    distances = dict(nx.all_pairs_dijkstra_path_length(G))
    D = np.zeros([n,n])
    for i in range(n):
        for j in range(n):
            D[i,j] = distances[i][j]
    
    return D

# %%
def isomap(G):
    N = len(G)
    D = get_distance_matrix(G)
    D = (D + D.T)/2    
    ones = np.ones([N,1])
    H = np.eye(N) - 1 / N * ones.dot(ones.T)
    C = -H.dot(D**2).dot(H)/(2*N)
    eigenvalues, eigenvectors = np.linalg.eig(C)
    index = np.argsort(-eigenvalues)
    Z = eigenvectors[:,index[0:2]].dot(np.diag(1/np.sqrt(eigenvalues[index[0:2]])))    
    return Z

# %%
N = len(images)

def compute_distance(x1, x2):
    return np.sqrt(np.sum((x1-x2)**2))
    
# generate adjacency matrix for nearest neighbor graph
G = np.zeros([N,N])
for i in range(N):
    for j in range(i,N):
        G[i,j] = G[j,i] = compute_distance(images[i], images[j])
        
Z = isomap(G)

# %%
_, ax = plt.subplots(figsize=(10,10))
ax.scatter(
        Z[:,0], 
        Z[:,1],
        marker="o",
        s=10,
        alpha=0.425,
        zorder=0,
    )
ax.axvline(x=0)

# %%
print(Z.shape)
Z_new = Z[Z[:,0] < 0]
images = images[Z[:,0] < 0]
filtered_names = png_files[Z[:,0] < 0]
print(Z_new.shape)
# Out:
# (116, 2)
# (58, 2)

# %%
pos_scores = []
styles = []
for name in filtered_names:
    index_str = name.replace('_flipped.png', '.jpg').replace('.png', '.jpg')
    pos_scores.append(shoe_pos_dict[index_str]['pos_score'])
    styles.append(shoe_pos_dict[index_str]['Style'])

# %%
import numpy as np
from matplotlib import offsetbox
from sklearn.preprocessing import MinMaxScaler

def plot_embedding(X, title):
    fig, ax = plt.subplots(figsize=(16,16))
    X = MinMaxScaler().fit_transform(X)
    color_mapping = {'Low Top': 'red', 'Mid Top': 'green', 'High Top': 'blue'}

    ax.scatter(
        X[:,0], 
        X[:,1],
        marker="o",
        c=pos_scores,
        cmap=plt.cm.viridis,
        s=10,
        alpha=0.425,
        zorder=0,
    )
    shown_images = np.array([[1.0, 1.0]])  # just something big
    for i in range(X.shape[0]):
        # plot every digit on the embedding
        # show an annotation box for a group of digits
        dist = np.sum((X[i] - shown_images) ** 2, 1)
        if np.min(dist) < 2e-3:
            # don't show points that are too close
            continue
        shown_images = np.concatenate([shown_images, [X[i]]], axis=0)
        imagebox = offsetbox.AnnotationBbox(
            offsetbox.OffsetImage(np.reshape(images[i], (250, 400)), zoom=0.12, cmap=plt.cm.gray_r), X[i], pad=0.5,
            bboxprops =dict(edgecolor=color_mapping[styles[i]])
        )
        imagebox.set(zorder=1)
        ax.add_artist(imagebox)

    ax.set_title(title)
    ax.axis("off")
    fig.savefig('./figures/isomap_embedding.png')

plot_embedding(Z_new, "ISOMAP Embedding")

# %%
fig, ax = plt.subplots(figsize=(10,10))
label_mapping = {1: 'guard', 2: 'forward', 3: 'center'}
scatter = ax.scatter(Z_new[:,0], Z_new[:,1], c=[round(x) for x in pos_scores], s = 20)
plt.legend(handles=scatter.legend_elements()[0], labels=list(label_mapping.values()))
fig.savefig('./figures/isomap_vs_position.png')

# %%
index = np.argsort(Z_new[:,0])[:6]
fig, axs = plt.subplots(2, 3, figsize=(20,10))
for i, ax in enumerate(axs.flatten()):
    ax.imshow(np.reshape(images[index[i]], (250,400)), cmap="gray")
    ax.set_title(f'Euclidean Embedding | Image {i+1}')
    ax.axis("off")
