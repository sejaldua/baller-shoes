# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import networkx as nx

# %%
pos_score_dict = {
    'Guard': 1,
    'Forward': 2,
    'Center': 3
}

player_df = pd.read_csv('./player-shoes-data.csv')
player_df['pos_score'] = player_df['Position'].apply(lambda x: pos_score_dict[x])
player_df
# Out:
#                        Player  \
# 0            Precious Achiuwa
# 1                Steven Adams
# 2                 Bam Adebayo
# 3                Santi Aldama
# 4    Nickeil Alexander-Walker
# ..                        ...
# 441            Thaddeus Young
# 442                Trae Young
# 443            Omer Yurtseven
# 444               Cody Zeller
# 445               Ivica Zubac
#
#                                       Player Page Link  \
# 0    https://ballershoesdb.com/players/precious-ach...
# 1      https://ballershoesdb.com/players/steven-adams/
# 2       https://ballershoesdb.com/players/bam-adebayo/
# 3      https://ballershoesdb.com/players/santi-aldama/
# 4    https://ballershoesdb.com/players/nickeil-alex...
# ..                                                 ...
# 441  https://ballershoesdb.com/players/thaddeus-young/
# 442      https://ballershoesdb.com/players/trae-young/
# 443  https://ballershoesdb.com/players/omer-yurtseven/
# 444     https://ballershoesdb.com/players/cody-zeller/
# 445     https://ballershoesdb.com/players/ivica-zubac/
#
#               Current Kicks Position  pos_score
# 0         Anta Daringly 3.0  Forward          2
# 1    New Balance Two Wxy V3   Center          3
# 2             Air Jordan 37  Forward          2
# 3          Nike Kyrie Low 5  Forward          2
# 4        Nike Kobe 5 Protro    Guard          1
# ..                      ...      ...        ...
# 441      Nike Kobe 6 Protro  Forward          2
# 442     Adidas Trae Young 2    Guard          1
# 443      Nike Kobe 5 Protro   Center          3
# 444           Air Jordan 37   Center          3
# 445  Adidas D.O.N. Issue #4   Center          3
#
# [446 rows x 5 columns]

# %%
import re
shoes_df = pd.read_csv('shoe-metadata.csv')
shoes_df['Number'] = shoes_df['Shoe Tag'].apply(lambda x: re.search(r'shoe_(\d+)\.jpg', x).group(1))
merged_df = shoes_df.merge(player_df, how='left', left_on='Shoe Name', right_on='Current Kicks')
# merged_df = merged_df.dropna(subset=['Player'])
grouped_df = merged_df.groupby(['Number', 'Shoe Tag', 'Shoe Name']).agg({'Player': 'count', 'pos_score': 'mean'}).reset_index()
# filtered_df = grouped_df[grouped_df['Player'] > 1]
sorted_df = grouped_df.copy()
sorted_df['Number'] = sorted_df['Number'].astype(int)
sorted_df = sorted_df.sort_values(by='Number')
shoe_files = list(sorted_df['Shoe Tag'].unique())
shoe_names = [x.replace('.jpg', '') for x in shoe_files]
shoe_pos_dict = sorted_df[['Shoe Tag', 'pos_score']].set_index('Shoe Tag').to_dict(orient='index')
print(len(shoe_files), shoe_names[:5])
# Out:
# 565 ['shoe_1', 'shoe_2', 'shoe_3', 'shoe_4', 'shoe_5']

# %%
sorted_df.sort_values(by='Player', ascending=False).head(30)
# Out:
#      Number      Shoe Tag                          Shoe Name  Player  \
# 295     370  shoe_370.jpg                 Nike Kobe 6 Protro      30
# 293     369  shoe_369.jpg                 Nike Kobe 5 Protro      29
# 351     422  shoe_422.jpg                          Nike PG 6      25
# 372     442  shoe_442.jpg                  Nike Zoom Freak 4      17
# 277     354  shoe_354.jpg                         Nike KD 15      16
# 311     385  shoe_385.jpg                       Nike Kyrie 7      16
# 243     322  shoe_322.jpg               Nike Air Zoom GT Cut      16
# 332     404  shoe_404.jpg                     Nike LeBron 20      15
# 244     323  shoe_323.jpg             Nike Air Zoom GT Cut 2      13
# 456      52   shoe_52.jpg                      Adidas Dame 8      12
# 26      122  shoe_122.jpg                      Air Jordan 37      11
# 320     394  shoe_394.jpg                   Nike Kyrie Low 5      10
# 314     389  shoe_389.jpg                Nike Kyrie Infinity      10
# 219     300  shoe_300.jpg             New Balance Two Wxy V3       9
# 276     353  shoe_353.jpg                         Nike KD 14       8
# 350     421  shoe_421.jpg                          Nike PG 5       7
# 384     454  shoe_454.jpg            Nike Zoom Kobe 4 Protro       7
# 477      54   shoe_54.jpg                   Adidas Exhibit A       7
# 25      121  shoe_121.jpg                      Air Jordan 36       6
# 245     324  shoe_324.jpg               Nike Air Zoom GT Run       5
# 438     503  shoe_503.jpg                    Puma Rise Nitro       5
# 379      45   shoe_45.jpg             Adidas D.O.N. Issue #4       5
# 310     384  shoe_384.jpg                       Nike Kyrie 6       5
# 297     372  shoe_372.jpg                Nike Kobe AD Exodus       5
# 86      179  shoe_179.jpg  Converse All Star BB Prototype CX       4
# 534       7    shoe_7.jpg            Adidas adiZero Rose 1.5       4
# 319     393  shoe_393.jpg                   Nike Kyrie Low 4       4
# 275     352  shoe_352.jpg                         Nike KD 13       3
# 170     256  shoe_256.jpg                      Jordan Zion 2       3
# 88      180  shoe_180.jpg         Converse All Star BB Shift       3
#
#      pos_score
# 295   1.466667
# 293   1.655172
# 351   1.720000
# 372   1.647059
# 277   2.062500
# 311   1.437500
# 243   1.625000
# 332   2.000000
# 244   1.307692
# 456   1.666667
# 26    1.727273
# 320   1.700000
# 314   1.600000
# 219   1.888889
# 276   1.875000
# 350   1.857143
# 384   1.571429
# 477   1.142857
# 25    1.833333
# 245   2.200000
# 438   1.600000
# 379   1.600000
# 310   1.800000
# 297   1.400000
# 86    1.500000
# 534   1.750000
# 319   1.500000
# 275   2.666667
# 170   2.000000
# 88    1.000000

# %%
import cv2
import numpy as np

def parse_png_directory(directory):
  """Parses a PNG directory and converts PNG files into NumPy arrays.

  Args:
    directory: The path to the PNG directory.

  Returns:
    A list of NumPy arrays, where each array represents one PNG file.
  """

  png_files = []
  for file in os.listdir(directory):
    if file.endswith(".png") and (file.replace('.png', '') in shoe_names or file.replace('_flipped.png', '') in shoe_names):
      png_files.append(file)

  numpy_arrays = []
  for png_file in png_files:
    numpy_array = cv2.imread(os.path.join(directory, png_file))
    grayscale_image = cv2.cvtColor(numpy_array, cv2.COLOR_RGB2GRAY)
    image_vec = np.reshape(grayscale_image, (-1,))
    numpy_arrays.append(image_vec)

  return np.vstack(numpy_arrays), np.array(png_files)

# %%
directory = "./cleaned_images"
images, png_files = parse_png_directory(directory)
images.shape
print(png_files[:10])
# Out:
# ['shoe_30.png' 'shoe_24.png' 'shoe_354_flipped.png' 'shoe_389.png'
#  'shoe_18.png' 'shoe_376.png' 'shoe_410.png' 'shoe_404.png' 'shoe_362.png'
#  'shoe_438.png']

# %%
fig, axs = plt.subplots(1, 3, figsize=(15,5))
random_nums = []
for i, ax in enumerate(axs.flatten()):
    random_num = np.random.choice(range(images.shape[0]))
    random_nums.append(random_num)
    ax.imshow(np.reshape(images[random_num], (250,400)), cmap="gray")
    ax.set_title(f"Image {random_num}")

# %%
def get_distance_matrix(W):
    # Assemble weighted edges matrix
    n = np.shape(W)[0]
    G = nx.DiGraph()
    for i in range(n):
        for j in range(n):
            G.add_weighted_edges_from([(i, j, min(W[i,j], W[j,i]))])
    
    # Implement dijkstra's algorithm to get distance matrix
    distances = dict(nx.all_pairs_dijkstra_path_length(G))
    D = np.zeros([n,n])
    for i in range(n):
        for j in range(n):
            D[i,j] = distances[i][j]
    
    return D

# %%
def principal_component_analysis(X, k):
     
    #Step 1: standardize the data
    X_meaned = X - np.mean(X , axis = 0)
     
    #Step 2: compute covariance matrix
    C = np.cov(X_meaned , rowvar = False)
     
    #Step 3: find eigengenvalues and eigenvectors using covariance matrix
    eigenvalues, eigenvectors = np.linalg.eigh(C)
     
    #Step 4: sort eigenvalues to find principal components
    sorted_index = np.argsort(eigenvalues)[::-1]
    sorted_eigenvalues = eigenvalues[sorted_index]
    sorted_eigenvectors = eigenvectors[:,sorted_index]
     
    #Step 5: select the top k principal components
    eigenvector_subset = sorted_eigenvectors[:,0:k]
     
    #Step 6: transform principal components for visualization
    X_transformed = np.dot(eigenvector_subset.transpose() , X_meaned.transpose() ).transpose()
     
    return X_transformed

# %%
N = len(images)

def compute_distance(x1, x2):
    return np.sqrt(np.sum((x1-x2)**2))
    
# generate adjacency matrix for nearest neighbor graph
G = np.zeros([N,N])
for i in range(N):
    for j in range(i,N):
        G[i,j] = G[j,i] = compute_distance(images[i], images[j])
        
Z = principal_component_analysis(G, 2)

# %%
_, ax = plt.subplots(figsize=(10,10))
ax.scatter(
        Z[:,0], 
        Z[:,1],
        marker="o",
        s=10,
        alpha=0.425,
        zorder=0,
    )
ax.axvline(x=0)

# %%
print(Z.shape)
Z_new = Z[Z[:,0] < 0]
images = images[Z[:,0] < 0]
filtered_names = png_files[Z[:,0] < 0]
print(Z_new.shape)
# Out:
# (1130, 2)
# (638, 2)

# %%
pos_scores = []
for name in filtered_names:
    index_str = name.replace('_flipped.png', '.jpg').replace('.png', '.jpg')
    pos_scores.append(shoe_pos_dict[index_str]['pos_score'])

# %%
import numpy as np
from matplotlib import offsetbox
from sklearn.preprocessing import MinMaxScaler

def plot_embedding(X, title):
    _, ax = plt.subplots(figsize=(20,20))
    X = MinMaxScaler().fit_transform(X)

    ax.scatter(
        X[:,0], 
        X[:,1],
        marker="o",
        c=pos_scores,
        cmap=plt.cm.viridis,
        s=10,
        alpha=0.425,
        zorder=0,
    )
    shown_images = np.array([[1.0, 1.0]])  # just something big
    for i in range(X.shape[0]):
        # plot every digit on the embedding
        # show an annotation box for a group of digits
        dist = np.sum((X[i] - shown_images) ** 2, 1)
        if np.min(dist) < 2e-3:
            # don't show points that are too close
            continue
        shown_images = np.concatenate([shown_images, [X[i]]], axis=0)
        imagebox = offsetbox.AnnotationBbox(
            offsetbox.OffsetImage(np.reshape(images[i], (250, 400)), zoom=0.12, cmap=plt.cm.gray_r), X[i], pad=0
        )
        imagebox.set(zorder=1)
        ax.add_artist(imagebox)

    ax.set_title(title)
    ax.axis("off")

plot_embedding(Z_new, "ISOMAP Embedding")

# %%
fig, ax = plt.subplots()
ax.scatter(Z_new[:,0], Z_new[:,1], c=pos_scores, cmap=plt.cm.copper, s = 20)
plt.show()

# %%
index = np.argsort(Z_new[:,0])[:6]
fig, axs = plt.subplots(2, 3, figsize=(20,10))
for i, ax in enumerate(axs.flatten()):
    ax.imshow(np.reshape(images[index[i]], (250,400)), cmap="gray")
    ax.set_title(f'Euclidean Embedding | Image {i+1}')
    ax.axis("off")

# %%
from sklearn.neighbors import KDTree
kdt = KDTree(Z_new, leaf_size=30, metric='euclidean')
distances, indices = kdt.query(Z_new, k=4, return_distance=True)
print(indices[0], distances[0])
# Out:
# [  0 598  91 337] [  0.         191.93804686 242.51862498 244.08496457]

# %%
target_shoe = np.where(filtered_names == 'shoe_300_flipped.png')[0][0]
print(png_files[target_shoe])
idx = indices[target_shoe]
dist = distances[target_shoe]
fig, axs = plt.subplots(1, 4, figsize=(30,5))
for i, ax in enumerate(axs.flatten()):
    ax.imshow(np.reshape(images[idx[i]], (250,400)), cmap="gray")
    ax.set_title(f'Euclidean Embedding | Image {idx[i]} | Distance {dist[i]}')
    ax.axis("off")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/SDua/Desktop/misc/baller-shoes/player-shoes-knn.ipynb Cell 18' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/SDua/Desktop/misc/baller-shoes/player-shoes-knn.ipynb#ch0000017?line=0'>1</a> target_shoe = np.where(filtered_names == 'shoe_300_flipped.png')[0][0]
#       <a href='vscode-notebook-cell:/Users/SDua/Desktop/misc/baller-shoes/player-shoes-knn.ipynb#ch0000017?line=1'>2</a> print(png_files[target_shoe])
#       <a href='vscode-notebook-cell:/Users/SDua/Desktop/misc/baller-shoes/player-shoes-knn.ipynb#ch0000017?line=2'>3</a> idx = indices[target_shoe]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
target_shoe = np.where(filtered_names == 'shoe_503.png')[0][0]
print(png_files[target_shoe])
idx = indices[target_shoe]
dist = distances[target_shoe]
fig, axs = plt.subplots(1, 4, figsize=(30,5))
for i, ax in enumerate(axs.flatten()):
    ax.imshow(np.reshape(images[idx[i]], (250,400)), cmap="gray")
    ax.set_title(f'Euclidean Embedding | Image {idx[i]} | Distance {dist[i]}')
    ax.axis("off")
# Out:
# shoe_95_flipped.png

# %%
target_shoe = np.where(filtered_names == 'shoe_179.png')[0][0]
print(png_files[target_shoe])
idx = indices[target_shoe]
dist = distances[target_shoe]
fig, axs = plt.subplots(1, 4, figsize=(30,5))
for i, ax in enumerate(axs.flatten()):
    ax.imshow(np.reshape(images[idx[i]], (250,400)), cmap="gray")
    ax.set_title(f'Euclidean Embedding | Image {idx[i]} | Distance {dist[i]}')
    ax.axis("off")
# Out:
# shoe_90_flipped.png
